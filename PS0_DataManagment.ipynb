# %% [markdown]
# <a href="https://colab.research.google.com/github/shirleyrutgers/DataManPy/blob/main/PS0_DataManagment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#PS0 Data Managment
